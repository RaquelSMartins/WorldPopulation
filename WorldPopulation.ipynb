# %% [markdown]
# <a href="https://colab.research.google.com/github/RaquelSMartins/WorldPopulation/blob/main/WorldPopulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise exploratória de dados - Um estudo sobre a População Mundial

# %% [markdown]
# ![alt text](https://businesstrumpet.com/wp-content/uploads/2022/07/world-population-global-population.jpg)

# %% [markdown]
# Image Credits: https://businesstrumpet.com/world-population-to-reach-8-billion-this-year-and-8-5-billion-by-2030/

# %% [markdown]
# ## Introdução (Background)

# %% [markdown]
# A atual estimativa da população mundial do US Census Bureau em junho de 2019 mostra que a população global atual é de 7.577.130.400 pessoas na Terra, o que excede em muito a população mundial de 7,2 bilhões em 2015. Nossa própria estimativa baseada em dados da ONU mostra que a população mundial ultrapassa 7,7 bilhões.
#
# Controle populacional é a prática de intervenção para alterar a taxa de crescimento da população. Historicamente, o controle populacional foi implementado através da limitação da taxa de natalidade de uma região, pela contracepção voluntária ou por mandato do governo. O estudo foi elaborado como uma resposta a fatores, incluindo níveis elevados ou crescentes de pobreza, as preocupações ambientais, e motivos religiosos. O uso de aborto em algumas estratégias de controle populacional tem causado controvérsias, com as organizações religiosas — como a Igreja Católica Romana — colocando-se explicitamente em oposição a qualquer intervenção no processo reprodutivo humano.
#
# A Universidade de Nebraska, através da publicação Illusions Green, argumenta que o controle populacional, como forma de aliviar as pressões ambientais, não precisa ser coercitivo. A universidade afirma que "as mulheres que são educadas, economicamente engajadas, e no controle de seus próprios corpos podem desfrutar da liberdade de ter filhos em seu próprio ritmo, que passa a ser uma taxa que é apropriada para a investidura ecológica agregada do nosso planeta."

# %% [markdown]
# **Objetivo do projeto**
#
# Analisar os dados populacionais de cada país no ano de 2022, identificando os países mais populosos e se a tendência deles é de crescimento ou decaimento populacional. Obter insights sobre os dados obtidos, traçando paralelos com parâmetros socioeconômicos globais.

# %% [markdown]
# **Critério de sucesso**
#
#  O projeto terá sido bem sucedido se os itens abaixo tiverem sido executados:
#
#  1) Identificar os 10 países mais populosos do mundo;
#
#  2) Identificar os 10 países com maior taxa de crescimento;
#
#  3) Interpretar os resultados obtidos sob a óptica socioeconômica mundial.

# %% [markdown]
# ## 1. Importação das Bibliotecas.

# %% [markdown]
# Abaixo estão as bibliotecas usadas:

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Seleção/ Limpeza/ Construção do Dado.
#
# Dataset Glossary (Column-Wise)
#
# Rank: Rank by Population.
#
# CCA3: 3 Digit Country/Territories Code.
#
# Country: Name of the Country/Territories.
#
# Capital: Name of the Capital.
#
# Continent: Name of the Continent.
#
# 2022 Population: Population of the Country/Territories in the year 2022.
#
# 2020 Population: Population of the Country/Territories in the year 2020.
#
# 2015 Population: Population of the Country/Territories in the year 2015.
#
# 2010 Population: Population of the Country/Territories in the year 2010.
#
# 2000 Population: Population of the Country/Territories in the year 2000.
#
# 1990 Population: Population of the Country/Territories in the year 1990.
#
# 1980 Population: Population of the Country/Territories in the year 1980.
#
# 1970 Population: Population of the Country/Territories in the year 1970.
#
# Area (km²): Area size of the Country/Territories in square kilometer.
#
# Density (per km²): Population Density per square kilometer.
#
# Growth Rate: Population Growth Rate by Country/Territories.
#
# World Population Percentage: The population percentage by each Country/Territories.

# %%
df = pd.read_csv("/content/world_population.csv")
# To display the top 5 rows 
df.head(5)
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.tail(5)                        # To display the botton 5 rows
# Out:
#      Rank CCA3            Country   Capital Continent  2022 Population  \
# 229   226  WLF  Wallis and Futuna  Mata-Utu   Oceania            11572
# 230   172  ESH     Western Sahara  El Aaiún    Africa           575986
# 231    46  YEM              Yemen     Sanaa      Asia         33696614
# 232    63  ZMB             Zambia    Lusaka    Africa         20017675
# 233    74  ZWE           Zimbabwe    Harare    Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 229            11655            12182            13142            14723
# 230           556048           491824           413296           270375
# 231         32284046         28516545         24743946         18628700
# 232         18927715         16248230         13792086          9891136
# 233         15669666         14154937         12839771         11834676
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Checagem dos tipos de dados

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (km²)                       int64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Limpeza dos dados - Dropando colunas irrelevantes

# %%
df = df.drop(['CCA3', 'Capital', '1970 Population', '1980 Population', '1990 Population'], axis=1)
df.head(5)
# Out:
#    Rank         Country Continent  2022 Population  2020 Population  \
# 0    36     Afghanistan      Asia         41128771         38972230
# 1   138         Albania    Europe          2842321          2866849
# 2    34         Algeria    Africa         44903225         43451666
# 3   213  American Samoa   Oceania            44273            46189
# 4   203         Andorra    Europe            79824            77700
#
#    2015 Population  2010 Population  2000 Population  Area (km²)  \
# 0         33753499         28189672         19542982      652230
# 1          2882481          2913399          3182021       28748
# 2         39543154         35856344         30774621     2381741
# 3            51368            54849            58230         199
# 4            71746            71519            66097         468
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# ...

# %% [markdown]
# ## 6. Verificação de linhas repetidas e exclusão

# %%
df.shape
# Out:
# (234, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
duplicate_rows_df = df[df.duplicated()]
print("numero de linhas duplicatas: ", duplicate_rows_df.shape)
# Out:
# numero de linhas duplicatas:  (0, 12)

# %% [markdown]
# Como pode haver 234 linhas se apenas existem 193 paises no mundo?

# %%
df.count()      # Used to count the number of rows
# Out:
# Rank                           234
# Country                        234
# Continent                      234
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# Area (km²)                     234
# Density (per km²)              234
# Growth Rate                    234
# World Population Percentage    234
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#    Rank         Country Continent  2022 Population  2020 Population  \
# 0    36     Afghanistan      Asia         41128771         38972230
# 1   138         Albania    Europe          2842321          2866849
# 2    34         Algeria    Africa         44903225         43451666
# 3   213  American Samoa   Oceania            44273            46189
# 4   203         Andorra    Europe            79824            77700
#
#    2015 Population  2010 Population  2000 Population  Area (km²)  \
# 0         33753499         28189672         19542982      652230
# 1          2882481          2913399          3182021       28748
# 2         39543154         35856344         30774621     2381741
# 3            51368            54849            58230         199
# 4            71746            71519            66097         468
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# ...

# %%
df.count()
# Out:
# Rank                           234
# Country                        234
# Continent                      234
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# Area (km²)                     234
# Density (per km²)              234
# Growth Rate                    234
# World Population Percentage    234
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# Não temos duplicatas! Então o que está acontecendo?
#
# O dataframe inclui territórios que são associados a países maiores, então é melhor deixar como está.

# %% [markdown]
# ## 7. Verificação de valores faltantes ou nulos.

# %%
df.isnull().sum()
# Out:
# Rank                           0
# Country                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Rank                           234
# Country                        234
# Continent                      234
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# Area (km²)                     234
# Density (per km²)              234
# Growth Rate                    234
# World Population Percentage    234
# dtype: int64

# %%
df.isnull().sum()   # After dropping the values
# Out:
# Rank                           0
# Country                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Histograma da população mundial

# %%
df.plot(x='Country', y= '2022 Population', kind= 'bar', figsize=(20, 10))

# %%
ordenado_por_pop_2022 = df.sort_values('2022 Population', ascending=False)

# %%
ordenado_por_pop_2022.head(10)
# Out:
#      Rank        Country      Continent  2022 Population  2020 Population  \
# 41      1          China           Asia       1425887337       1424929781
# 92      2          India           Asia       1417173173       1396387127
# 221     3  United States  North America        338289857        335942003
# 93      4      Indonesia           Asia        275501339        271857970
# 156     5       Pakistan           Asia        235824862        227196741
# 149     6        Nigeria         Africa        218541212        208327405
# 27      7         Brazil  South America        215313498        213196304
# 16      8     Bangladesh           Asia        171186372        167420951
# 171     9         Russia         Europe        144713314        145617329
# 131    10         Mexico  North America        127504125        125998302
#
#      2015 Population  2010 Population  2000 Population  Area (km²)  \
# 41        1393715448       1348191368       1264099069     9706961
# ...

# %%
ordenado_por_pop_2022_limpo = ordenado_por_pop_2022.drop(['2020 Population', '2015 Population', '2010 Population', '2000 Population'], axis=1)
ordenado_por_pop_2022_limpo.head(10)
# Out:
#      Rank        Country      Continent  2022 Population  Area (km²)  \
# 41      1          China           Asia       1425887337     9706961
# 92      2          India           Asia       1417173173     3287590
# 221     3  United States  North America        338289857     9372610
# 93      4      Indonesia           Asia        275501339     1904569
# 156     5       Pakistan           Asia        235824862      881912
# 149     6        Nigeria         Africa        218541212      923768
# 27      7         Brazil  South America        215313498     8515767
# 16      8     Bangladesh           Asia        171186372      147570
# 171     9         Russia         Europe        144713314    17098242
# 131    10         Mexico  North America        127504125     1964375
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 41            146.8933       1.0000                        17.88
# 92            431.0675       1.0068                        17.77
# ...

# %%
top10_pop_2022 = ordenado_por_pop_2022_limpo.head(10)

top10_pop_2022.plot(x = 'Country', y = '2022 Population', kind = 'bar', figsize=(9,5))

plt.title("Os 10 paísses mais populosos do mundo")
plt.show()

# %%
ordenado_por_GR_2022 = df.sort_values('Growth Rate', ascending = False)
ordenado_por_GR_2022.head(10)
# Out:
#      Rank   Country Continent  2022 Population  2020 Population  \
# 133   135   Moldova    Europe          3272996          3084847
# 164    37    Poland    Europe         39857145         38428366
# 148    54     Niger    Africa         26207977         24333639
# 202    60     Syria      Asia         22125249         20772595
# 189   116  Slovakia    Europe          5643453          5456681
# 55     15  DR Congo    Africa         99010212         92853164
# 130   182   Mayotte    Africa           326101           305587
# 39     69      Chad    Africa         17723315         16644701
# 5      42    Angola    Africa         35588987         33428485
# 124    59      Mali    Africa         22593590         21224040
#
#      2015 Population  2010 Population  2000 Population  Area (km²)  \
# 133          3277388          3678186          4251573       33846
# 164         38553146         38597353         38504431      312679
# ...

# %% [markdown]
# #Como podemos notar, dos 10 países com maior Taxa de Crescimento do mundo, 6 deles são da África.
#
# #Nota-se ainda que quando ranqueamos por Taxa de Crescimento, os 10 países mais populosos do mundo não aparecem.

# %%
ordenado_por_pop_2022_TIMELINE = ordenado_por_pop_2022.drop(['Rank', 'Continent', 'Area (km²)', 'Density (per km²)', 'Growth Rate', 'World Population Percentage'], axis = 1)
ordenado_por_pop_2022_TIMELINE.head(10)
TIMELINE = ordenado_por_pop_2022_TIMELINE.rename(columns= {'2022 Population' : 2022, '2020 Population' : 2020, '2015 Population' : 2015, '2010 Population' : 2010, '2000 Population' : 2000})

TIMELINE.head(10)
# Out:
#            Country        2022        2020        2015        2010        2000
# 41           China  1425887337  1424929781  1393715448  1348191368  1264099069
# 92           India  1417173173  1396387127  1322866505  1240613620  1059633675
# 221  United States   338289857   335942003   324607776   311182845   282398554
# 93       Indonesia   275501339   271857970   259091970   244016173   214072421
# 156       Pakistan   235824862   227196741   210969298   194454498   154369924
# 149        Nigeria   218541212   208327405   183995785   160952853   122851984
# 27          Brazil   215313498   213196304   205188205   196353492   175873720
# 16      Bangladesh   171186372   167420951   157830000   148391139   129193327
# 171         Russia   144713314   145617329   144668389   143242599   146844839
# 131         Mexico   127504125   125998302   120149897   112532401    97873442

# %%
#Diferença entre as populações da China em 2010 e 2000
1348191368 - 1264099069
# Out:
# 84092299

# %%
#Diferença entre as populações da China em 2020 e 2010
1424929781 - 1348191368
# Out:
# 76738413

# %%
#Diferença entre os resultados:
76738413 - 84092299
# Out:
# -7353886

# %%
ordenado_por_GR_2022_TIMELINE = ordenado_por_GR_2022.drop(['Rank','Area (km²)', 'Density (per km²)', 'World Population Percentage'], axis = 1)
ordenado_por_GR_2022_TIMELINE.head(10)
# Out:
#       Country Continent  2022 Population  2020 Population  2015 Population  \
# 133   Moldova    Europe          3272996          3084847          3277388
# 164    Poland    Europe         39857145         38428366         38553146
# 148     Niger    Africa         26207977         24333639         20128124
# 202     Syria      Asia         22125249         20772595         19205178
# 189  Slovakia    Europe          5643453          5456681          5424444
# 55   DR Congo    Africa         99010212         92853164         78656904
# 130   Mayotte    Africa           326101           305587           249545
# 39       Chad    Africa         17723315         16644701         14140274
# 5      Angola    Africa         35588987         33428485         28127721
# 124      Mali    Africa         22593590         21224040         18112907
#
#      2010 Population  2000 Population  Growth Rate
# 133          3678186          4251573       1.0691
# ...

# %%
#Diferença entre as populações da Nigéria em 2010 e 2000
16647543	- 11622665
# Out:
# 5024878

# %%
#Diferença entre as populações da Nigéria em 2010 e 2000
24333639 - 16647543
# Out:
# 7686096

# %%
#Diferença entre os resultados: 
7686096 - 5024878
# Out:
# 2661218

# %% [markdown]
# #**Avaliação final**
#
# Segundo os dados, podemos concluir que os 10 países mais populosos do mundo são: China, Índia, EUA, Indonésia, Pakistão, Nigéria, Brasil, Bangladesh, Rússia e México.
#
# Os páises com maior taxa de crescimento são: Moldova, Polônia, Nigéria, Síria, Eslovaquia, Congo, Maiotte, Chad, Angola e Mali. Desses 10, 6 estão localizados no continente africano.
#
# Os dados mostram que a China, segundo a taxa de crescimento, tende estabilizar/a sua população.
